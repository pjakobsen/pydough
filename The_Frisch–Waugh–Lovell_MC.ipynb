# %% [markdown]
# <a href="https://colab.research.google.com/github/pjakobsen/pydough/blob/main/The_Frisch%E2%80%93Waugh%E2%80%93Lovell_MC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### A quick example of how to work with data files for John Wasef

# %%
# example of effect of size on monte carlo sample
from numpy.random import normal
from matplotlib import pyplot
# define the distribution
mu = 50
sigma = 5
# generate monte carlo samples of differing size
sizes = [10, 50, 100, 1000]
for i in range(len(sizes)):
	# generate sample
	sample = normal(mu, sigma, sizes[i])
	# plot histogram of sample
	pyplot.subplot(2, 2, i+1)
	pyplot.hist(sample, bins=20)
	pyplot.title('%d samples' % sizes[i])
	pyplot.xticks([])
# show the plot
pyplot.show()

# %% [markdown]
# The Frisch--Waugh--Lovell Theorem for Standard Errors
#
# Peng Ding, Harvard University

# %%
import pandas as pd
import numpy as np

obs = 50
# generate the explanatory variables (here we simulate 2 variables from a normal distribution)
# Mean of 5, SD of 3
x1 = normal(10,2)
x2 = normal(9,1)

x1,x2

df = pd.DataFrame(np.random.randint(0,100,size=(15, 2)), columns=['X1','X2'])
df.head()
# Out:
#    X1  X2
# 0  31  46
# 1  48  94
# 2  43  27
# 3  78  55
# 4   9  33

# %%
import matplotlib.pyplot as plt

x1 = [2, 3, 4]
y1 = [5, 5, 5]

x2 = [1, 2, 3, 4, 5]
y2 = [2, 3, 2, 3, 4]
y3 = [6, 8, 7, 8, 7]

# Markers: https://matplotlib.org/api/markers_api.html

plt.scatter(x1, y1)
plt.scatter(x2, y2, marker='v', color='r')
plt.scatter(x2, y3, marker='^', color='m')
plt.title('Scatter Plot Example')
plt.show()

# %%
obs = 50
from scipy.stats import norm
# 100 random values from a Normal distribution with mu = 1.0
x1 = norm.rvs(loc=10, scale=2, size=obs)
x2 = norm.rvs(loc=0.0, scale=1.0, size=obs)
e =  norm.rvs(loc=0.0, scale=1.0, size=obs)

y = 0.5*x1 + 0.9*x2 + e

# For plotting this is the best reference

import matplotlib.pyplot as plt
plt.scatter(y,x1)
plt.scatter(y,x2,marker='v', color='r')
plt.title('Scatter Plot Example')
plt.show()

# %% [markdown]
# They key insight.   Dougherty Chapeter 3.4. the greater the variance of any estimator the more precise the model, because that greater varience means more random variation has been sucked out of the error term that would otherwise be in that error term. Do the math.
#
# For plotting this is the best reference:
#
# https://colab.research.google.com/notebooks/charts.ipynb#scrollTo=el13bTbyPRw4

# %%
import seaborn as sns
sns.regplot(y,x1)
sns.regplot(y,x2)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Show the advantages of the built in Altair library combined with Econtools to display and visualize Dougherty Datasets. Pandas can also read Stata Files

# %%
import altair as alt
# from vega_datasets import data
#Subset21

df = pd.read_excel('http://global.oup.com/uk/orc/busecon/economics/dougherty5e/student/datasets/eawe/excel/EAWE21.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0fcd72d172cb> in <module>()
#       4
#       5 #df = pd.read_excel('http://global.oup.com/uk/orc/busecon/economics/dougherty5e/student/datasets/eawe/excel/EAWE21.xlsx')
# ----> 6 df = pd.read_stata('http://global.oup.com/uk/orc/busecon/economics/dougherty5e/student/datasets/oecd/stata/oecd.dta')
#
# NameError: name 'pd' is not defined

# %%
"'df1 = df[['S', 'AGE']]
# df1  = df1.astype(int, errors='ignore')
df1.isnull().sum()

alt.Chart(df).mark_circle().encode(
  x='AGE',
  y='S',
)
# Out:
# alt.Chart(...)

# %%
from vega_datasets import local_data
#local_data.list_datasets()

# %%
list(df.columns)
df.dtypes
alt.Chart(df).mark_circle(size=60).encode(
    x='S',
    y='EARNINGS',
    color='Origin',
    tooltip=['Name', 'Origin', 'Horsepower', 'Miles_per_Gallon']
).interactive()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# /usr/local/lib/python3.6/dist-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
# --> 328                 context=context,
#     329             )
#     330         else:
#
# /usr/local/lib/python3.6/dist-packages/altair/utils/schemapi.py in _todict(obj, validate, context)
#      60         return {
#      61             k: _todict(v, validate, context)
# ...
